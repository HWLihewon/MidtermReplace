# %%
#3주차

# %%
strVal = 'data science'               # 문자열 변수
nVal = 12345                          # 정수형 변수
fVal = 1.2                            # 실수형 변수
lVal = ['data', 'science']            # 리스트
dVal = {'lecture' : 'data science'}   # 딕셔너리
bVal = True                           # 논리형 변수(참/거짓)

# %%
# 기본적인 주석
''' 
이런 형태의 주석도 많이 사용
'''
# Out:
# ' \n이런 형태의 주석도 많이 사용\n'

# %%
strVal
# Out:
# 'data science'

# %%
nVal
# Out:
# 12345

# %%
fVal
# Out:
# 1.2

# %%
lVal
# Out:
# ['data', 'science']

# %%
dVal
# Out:
# {'lecture': 'data science'}

# %%
bVal
# Out:
# True

# %%
print('strVal : ', strVal)
print('nVal : ', nVal)
print('fVal : ', fVal)
print('lVal : ', lVal)
print('dVal : ', dVal)
print('bVal : ', bVal)
# Out:
# strVal :  data science
# nVal :  12345
# fVal :  1.2
# lVal :  ['data', 'science']
# dVal :  {'lecture': 'data science'}
# bVal :  True

# %%
print('strVal : ', type(strVal))
print('nVal : ', type(nVal))
print('fVal : ', type(fVal))
print('lVal : ', type(lVal))
print('dVal : ', type(dVal))
print('bVal : ', type(bVal))
# Out:
# strVal :  <class 'str'>
# nVal :  <class 'int'>
# fVal :  <class 'float'>
# lVal :  <class 'list'>
# dVal :  <class 'dict'>
# bVal :  <class 'bool'>

# %%
'''
같은 변수명일 경우, 이전 데이터를 덮어씀
'''
nVal = 16                          # 정수형 변수
fVal = 3.14                        # 실수형 변수

# %%
print('10진수 표현 : ', nVal)       # 10진수
print('2진수 표현 : ', bin(nVal))  # 2진수
print('8진수 표현 : ', oct(nVal))  # 8진수
print('16진수 표현 : ', hex(nVal))  # 16진수
# Out:
# 10진수 표현 :  16
# 2진수 표현 :  0b10000
# 8진수 표현 :  0o20
# 16진수 표현 :  0x10

# %%
btVal = True                           # 논리형 변수(참)
bfVal = False                          # 논리형 변수(거짓)

# %%
btVal = TRUE                          # 논리형 변수(참) - 오류
bfVal = FALSE                          # 논리형 변수(거짓) - 오류
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2634659662.py in <module>
# ----> 1 btVal = TRUE                          # 논리형 변수(참) - 오류
#       2 bfVal = FALSE                          # 논리형 변수(거짓) - 오류
#
# NameError: name 'TRUE' is not defined

# %%
btVal = true                          # 논리형 변수(참) - 오류
bfVal = false                          # 논리형 변수(거짓) - 오류
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2305073268.py in <module>
# ----> 1 btVal = true                          # 논리형 변수(참) - 오류
#       2 bfVal = false                          # 논리형 변수(거짓) - 오류
#
# NameError: name 'true' is not defined

# %%
10 == 11
# Out:
# False

# %%
10 != 11
# Out:
# True

# %%
10 >= 11
# Out:
# False

# %%
10 <= 11
# Out:
# True

# %%
10 > 11
# Out:
# False

# %%
10 < 11
# Out:
# True

# %%
nBig = 100
nSmall = 10

# %%
print(nBig == nSmall)
print(nBig != nSmall)
print(nBig >= nSmall)
print(nBig <= nSmall)
print(nBig > nSmall)
print(nBig < nSmall)
# Out:
# False
# True
# True
# False
# True
# False

# %%
print(nBig =< nSmall)     # 오류
# Out:
#   File "C:\Users\H\AppData\Local\Temp\ipykernel_18012\2286930918.py", line 1
#     print(nBig =< nSmall)     # 오류
#                 ^
# SyntaxError: invalid syntax

# %%
print(nBig => nSmall)     # 오류
# Out:
#   File "C:\Users\H\AppData\Local\Temp\ipykernel_18012\1053890005.py", line 1
#     print(nBig => nSmall)     # 오류
#                 ^
# SyntaxError: invalid syntax

# %%
strData = 'data'               # 문자열 변수
strSci = "Science"             # 문자열 변수

# %%
strLecture = strData + strSci

# %%
strLecture
# Out:
# 'dataScience'

# %%
strLecture = strData +" "+ strSci
strLecture
# Out:
# 'data Science'

# %%
strLecture.split()              # split()으로 공백을 기준으로 문자열 구분
# Out:
# ['data', 'Science']

# %%
lSeperate = strLecture.split() # split()으로 공백을 기준으로 문자열 구분아혀 lSeperate 변수에 저장

# %%
type(lSeperate)
# Out:
# list

# %%
strHello = "안녕하세요. 반갑습니다."

# %%
strHello.find("반갑")       # 문자열을 찾기 위해 find() 함수를 이용
                            # 문자열을 있으면, 첫번째 시작 인덱스를 반환
# Out:
# 7

# %%
strHello.find("hello")    # 문자열이 없으면, -1을 리턴
# Out:
# -1

# %%
"반갑" in strHello          # in 명령어를 사용하여 확인 가능 : if 조건문에서 활용
# Out:
# True

# %%
strHello.replace('.', '?')    # .을 모두 ?로 변경
# Out:
# '안녕하세요? 반갑습니다?'

# %%
strHello.replace('.', '?')                  
strHello.replace("하세요", "하셔유")       # 안녕하셔유? 가 될까요?
# Out:
# '안녕하셔유. 반갑습니다.'

# %%
strHello                      # 원본 데이터는 변하지 않음
# Out:
# '안녕하세요. 반갑습니다.'

# %%
strNewHello = strHello.replace('.', '?')                    # strHello를 replace하여 strNewHello에 저장   
strNewHello = strNewHello.replace("하세요", "하셔유")       # strNewHello를 replace하여 strNewHello에 저장
strNewHello
# Out:
# '안녕하셔유? 반갑습니다?'

# %%
strHello.strip('반갑습니다.')    # strip()함수를 이용하여 "반갑습니다."를 제거
# Out:
# '안녕하세요. '

# %%
strHello                    # 역시 원본 데이터는 변하지 않음
# Out:
# '안녕하세요. 반갑습니다.'

# %%
lnData = [1,2,3,4,5]     # lnData를 리스트로 생성
print(lnData)
print('type : ', type(lnData))
# Out:
# [1, 2, 3, 4, 5]
# type :  <class 'list'>

# %%
print(lnData[0])    # lnData 리스트의 0번 인덱스의 값 출력
print(lnData[3])    # lnData 리스트의 3번 인덱스의 값 출력
# Out:
# 1
# 4

# %%
lnData[0] = lnData[4]   # lnData[4]의 값을 lnData[0]에 저장
print(lnData)           # lnData 리스트를 출력
# Out:
# [5, 2, 3, 4, 5]

# %%
print(lnData[2:4])      # lnData[4]에 저장된 5는 출력되지 않음
# Out:
# [3, 4]

# %%
lnData = [1,2,3,4,5]
lstrData=['a', 'b', 'c']

# 두 개의 서로다른 자료형을 가진 리스트를 병합
lnData + lstrData
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c']

# %%
lnData.append(10)   # 10을 맨 뒤에 추가
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
lnData.insert(0, 'python')  #'python'문자열을 0번 인덱스에 추가하고, 기존 인덱스에 저장된 데이터는 하나씩 뒤로 밀림(인덱스가 +1 추가)
lnData
# Out:
# ['python', 1, 2, 3, 4, 5, 10]

# %%
lnData.remove('python')     # 'python' 데이터를 삭제
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
del lnData[5]              # del 명령어를 통해 인덱스를 지정하여 삭제
lnData
# Out:
# [1, 2, 3, 4, 5]

# %%
lnData
# Out:
# [1, 2, 3, 4, 5]

# %%
lnData.pop(0)     # 0번 인덱스의 데이터를 삭제
lnData
# Out:
# [2, 3, 4, 5]

# %%
lnData.pop()     # 인덱스 지정이 없으면, 마지막 인덱스의 값을 삭제
lnData
# Out:
# [2, 3, 4]

# %%
lnData.clear()  # 리스트의 모든 데이터를 삭제
lnData
# Out:
# []

# %%
# 튜플의 기본 구조
tVal = ("사과", "딸기", "바나나", "토마토", "키위")

print(tVal)
print(type(tVal))
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위')
# <class 'tuple'>

# %%
# 튜플에 저장된 데이터는 변경이 불가능
tVal[0] = "포도"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2072098934.py in <module>
#       1 # 튜플에 저장된 데이터는 변경이 불가능
# ----> 2 tVal[0] = "포도"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# count() 함수를 이용하여 튜플에 저장된 특정 데이터의 개수를 확인
tData = ( 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)
tData.count(1)
# Out:
# 3

# %%
# len()함수를 이용하여 튜플에 저장된 전체 데이터 개수를 확인
len(tVal)
# Out:
# 5

# %%
len(tData)
# Out:
# 11

# %%
print(tData[2:5])
# Out:
# (3, 1, 2)

# %%
tTuple = tVal+ tData
print(tTuple)
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위', 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData * 2
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData2 = tData * 2
print(tData2)
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal * 2
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x27194ce6e10
# tVal memory =  0x2719cad5bc0
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal + tVal
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x2719cad5bc0
# tVal memory =  0x2719d642b50
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
sVal = {1, 2, 3, 4, 5}
print(sVal)
print(type(sVal))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
sVal[1:2]     #리스트와 튜플같은 인덱스가 없기 때문에, 인덱싱 관련 연산은 불가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\468339363.py in <module>
# ----> 1 sVal[1:2]
#
# TypeError: 'set' object is not subscriptable

# %%
# add 함수를 이용하여 데이터를 추가할 수 있음
sVal.add(100)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100}

# %%
# update 함수를 이용하여 여러개의 데이터를 추가할 수 있음
sVal.update([200, 300])
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 200, 300}

# %%
# remove 함수를 이용하여 데이터를 삭제할 수 있음
sVal.remove(200)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 300}

# %%
# clear() 함수를 이용하여 데이터를 초기화 할 수 있음
sVal.clear()
print(sVal)
# Out:
# set()

# %%
sVal = {100, 200, 300, 400, 500}
sData = {"a", "b", "c", "c", 100, 300}
print(sVal)
print(sData)
# Out:
# {400, 100, 500, 200, 300}
# {'b', 'a', 100, 'c', 300}

# %%
# intersection() 함수를 이용하여 교집합을 만들 수 있음
sVal.intersection(sData)
# Out:
# {100, 300}

# %%
# deference() 함수를 이용하여 차집합을 만들 수 있음
sVal.difference(sData)
# Out:
# {200, 400, 500}

# %%
# "-" 연산자로도 가능
sVal - sData
# Out:
# {200, 400, 500}

# %%
# union() 함수를 이용하여 합집합을 만들 수 있음
sVal.union(sData)
# Out:
# {100, 200, 300, 400, 500, 'a', 'b', 'c'}

# %%
# "+"연산자는 불가능
sVal + sData
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\3037826460.py in <module>
#       1 # "+"연산자는 불가능
# ----> 2 sVal + sData
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
# symetric_difference()를 이용하여 합집합에서 교집합을 뺀 집합을 만들 ㅅ ㅜ있음
sVal.symmetric_difference(sData)
# Out:
# {200, 400, 500, 'a', 'b', 'c'}

# %%
# 딕셔너리 기본 구조는 다음과 같이 표현할 수 있음
dVal = {
    'name' : '이컴공',
    'email' : 'computer@hoseo.edu',
    'address' : '충남 아산시'
}
print(dVal)
print(type(dVal))
# Out:
# {'name': '이컴공', 'email': 'computer@hoseo.edu', 'address': '충남 아산시'}
# <class 'dict'>

# %%
dData = {
    "사과" : 300, 
    "포도" : 200, 
    "배" : 500,
    "키위" : 100
}

# %%
# 키를 이용한 항목 검색
print(dData["배"])
# Out:
# 500

# %%
# get() 함수를 이용한 항목 검색
dData.get("배")
# Out:
# 500

# %%
# 새로운 키 추가를 통한 항목 추가
dData["딸기"] = 100
print(dData)
# Out:
# {'사과': 300, '포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
# pop을 이용한 항목 삭제
dData.pop("사과")
# Out:
# 300

# %%
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
dData.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2765138924.py in <module>
# ----> 1 dData.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
# sorted 함수를 이용한 정렬
sorted(dData)
# Out:
# ['딸기', '배', '키위', '포도']

# %%
# sorted와 values 함수를 이용하여 값을 정렬할 수 있음
sorted(dData.values())
# Out:
# [100, 100, 200, 500]

# %%
# 실제 dData는 변화가 없음
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
def 함수명 (입력값):     #함수를 사용해 구조를 효율적으로 만듦
    수행문1
    수행문2
    return 출력값

# %%
# 함수 f(x)를 생성하고 x 값을 입력으로 받음
def f(x):
  # x에 10을 더한 값을 출력
  return x + 10

# %%
f(2)
# Out:
# 12

# %%
# 4 주차

# %%
# 내장함수 예 : input
strText = input("아무 문장이나 입력하세요 : ")
print(strText)
# Out:
# 아무 문장이나 입력하세요 : ddd
# ddd

# %%
# List를 이용한 다차원 배열
flVal = [1.0, 2.0, 3.14, 4.2, 5.1]  # 실수 list를 생성

# %%
# flVal 3개를 리스트로 구성하여 arVal 다차원 배열을 생성
arVal = [flVal, flVal, flVal]
arVal
# Out:
# [[1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
# arVal은 다차원 배열이므로, arVal[n] 인덱스 연산을 통해 n차원 배열 값을 출력
arVal[0]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1][2]
# Out:
# 3.14

# %%
# 1 차원 값을 변환하여 다른 값을 대입 했을때의 다차원 배열
arVal[0] = 'python'
arVal
# Out:
# ['python', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
arVal[0][2]
# Out:
# 't'

# %%
arVal[0] = 'python programming'
arVal
# Out:
# ['python programming', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
# numpy 패치지를 import 
import numpy as np
arData = np.array([1.0, 2.0, 3.14, 4.2, 5.1])
arData
# Out:
# array([1.  , 2.  , 3.14, 4.2 , 5.1 ])

# %%
# 배열 각 요소의 합을 출력
arData.sum()
# Out:
# 15.44

# %%
arVal.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\2999335311.py in <module>
# ----> 1 arVal.sum()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
print(type(arVal))
print(type(arData))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
# 배열에 대한 표준편차 출력
arData.std()
# Out:
# 1.4717934637713266

# %%
# 배열의 누적 합을 출력
arData.cumsum()
# Out:
# array([ 1.  ,  3.  ,  6.14, 10.34, 15.44])

# %%
arData * 2
# Out:
# array([ 2.  ,  4.  ,  6.28,  8.4 , 10.2 ])

# %%
arData ** 2 # 2를 제곱
# Out:
# array([ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ])

# %%
# 루트를 적용한 값을 출력
np.sqrt(arData)
# Out:
# array([1.        , 1.41421356, 1.77200451, 2.04939015, 2.25831796])

# %%
arVal = np.array([arData, arData ** 2])
arVal
# Out:
# array([[ 1.    ,  2.    ,  3.14  ,  4.2   ,  5.1   ],
#        [ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ]])

# %%
arVal.sum(axis=0) # 축(axis)이 0일 경우 세로 축의 합을 출력
# Out:
# array([ 2.    ,  6.    , 12.9996, 21.84  , 31.11  ])

# %%
arVal.sum(axis=1) # 축(axis)이 0일 경우 가로 축의 합을 출력
# Out:
# array([15.44  , 58.5096])

# %%
# NumPy.array를 사용한 코드
np.array([[0,0,0],[0,0,0]])
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
# NumPy.zeros를 사용한 코드
arZero = np.zeros((2,3), dtype = 'i') 
arZero
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %%
# pandas import
import pandas as pd

pandas_series = pd.Series([30, 20, 10], index=['국어', '영어', '수학'])
print(type(pandas_series))
pandas_series
# Out:
# <class 'pandas.core.series.Series'>
# 국어    30
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[1:]
# Out:
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[0]
# Out:
# 30

# %%
pandas_series[0][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\3046292380.py in <module>
# ----> 1 pandas_series[0][1]
#
# IndexError: invalid index to scalar variable.

# %%
df = pd.DataFrame([30,20,10], columns=['score'], index=['국어', '영어', '수학'])
df
# Out:
#     score
# 국어     30
# 영어     20
# 수학     10

# %%
# DataFrame의 index를 표시
df.index
# Out:
# Index(['국어', '영어', '수학'], dtype='object')

# %%
# DataFrame의 column을 표시
df.columns
# Out:
# Index(['score'], dtype='object')

# %%
# DataFrame의index 중에서 국어에 해당하는 값을 출력
df.loc['국어']   # ix 함수가 최근 제거되어 loc를 써야 동작
# Out:
# score    30
# Name: 국어, dtype: int64

# %%
# DataFrame의 값을 모두 합한 결과를 출력
df.sum()
# Out:
# score    60
# dtype: int64

# %%
# DataFrame의 각 colimn 값의 제곱을 출력
df.score ** 2
# Out:
# 국어    900
# 영어    400
# 수학    100
# Name: score, dtype: int64

# %%
# DataFrame에 score2 라는 칼럼을 추가하고 값을 입력
df['score2'] = (50, 50, 50)
df
# Out:
#     score  score2
# 국어     30      50
# 영어     20      50
# 수학     10      50

# %%
# DataFrame 함수를 이용하여 column을 추가할 수 있음
df['score2'] = pd.DataFrame([90,90,90], index=['국어', '영어', '수학'])
df
# Out:
#     score  score2
# 국어     30      90
# 영어     20      90
# 수학     10      90

# %%
# column 삭제
del df['score']

# %%
# index 를 맞추기 않았을 경우
df['score2'] = (90, 90, 90, 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\1894884841.py in <module>
#       1 # index 를 맞추기 않았을 경우
# ----> 2 df['score2'] = (90, 90, 90, 100)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (3)

# %%
# index 를 맞추기 않았을 경우
df['score2'] = pd.DataFrame([90, 90, 90, 100], index=['국어', '영어', '수학', '윤리'])
df
# Out:
#     score2
# 국어      90
# 영어      90
# 수학      90

# %%
# join() 함수를 이용하여 2개의 DataFrame을 하나로 합칠 수 있음
df1 = pd.DataFrame([1, 2, 3], columns = ['A'])
df2 = pd.DataFrame([10, 11, 12, 13], columns = ['B'])

df = df1.join(df2, how='outer')
df
# Out:
#      A   B
# 0  1.0  10
# 1  2.0  11
# 2  3.0  12
# 3  NaN  13

# %%
df_inner = df1.join(df2, how='inner')
df_inner
# Out:
#    A   B
# 0  1  10
# 1  2  11
# 2  3  12

# %%
# 난수를 이용한 임의의 값 생성
df = pd.DataFrame(np.random.randn(5,5))
df.columns = ['A', 'B', 'C', 'D', 'E']

df
# Out:
#           A         B         C         D         E
# 0  0.295738  0.661110  0.298091 -0.642416 -0.884737
# 1  2.305701  0.782602 -0.978401  0.306382 -0.699455
# 2  0.265406 -0.736892  0.463714 -0.884278 -0.012699
# 3 -0.242388  0.282036  0.938061 -0.507126 -1.149804
# 4  0.176647 -0.426171  1.081067 -2.115161 -0.149782

# %%
# 최대값
df.max()
# Out:
# A    2.305701
# B    0.782602
# C    1.081067
# D    0.306382
# E   -0.012699
# dtype: float64

# %%
# 최소값
df.min()
# Out:
# A   -0.242388
# B   -0.736892
# C   -0.978401
# D   -2.115161
# E   -1.149804
# dtype: float64

# %%
# 평균
df.mean()
# Out:
# A    0.560221
# B    0.112537
# C    0.360506
# D   -0.768520
# E   -0.579295
# dtype: float64

# %%
# 표준편차
df.std()
# Out:
# A    0.999359
# B    0.669026
# C    0.815475
# D    0.875569
# E    0.484439
# dtype: float64

# %%
# 누적값
df.cumsum()
# Out:
#           A         B         C         D         E
# 0  0.295738  0.661110  0.298091 -0.642416 -0.884737
# 1  2.601439  1.443712 -0.680311 -0.336034 -1.584192
# 2  2.866845  0.706820 -0.216597 -1.220312 -1.596891
# 3  2.624457  0.988856  0.721464 -1.727438 -2.746695
# 4  2.801104  0.562685  1.802531 -3.842599 -2.896477

# %%
# DataFrame의 통계적 요약
df.describe()
# Out:
#               A         B         C         D         E
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.560221  0.112537  0.360506 -0.768520 -0.579295
# std    0.999359  0.669026  0.815475  0.875569  0.484439
# min   -0.242388 -0.736892 -0.978401 -2.115161 -1.149804
# 25%    0.176647 -0.426171  0.298091 -0.884278 -0.884737
# 50%    0.265406  0.282036  0.463714 -0.642416 -0.699455
# 75%    0.295738  0.661110  0.938061 -0.507126 -0.149782
# max    2.305701  0.782602  1.081067  0.306382 -0.012699

# %%
# Group by를 이용한 DataFrame의 그룹화
df['division'] = ['X', 'Y', 'X', 'Y', 'Z']
df
# Out:
#           A         B         C         D         E division
# 0  0.295738  0.661110  0.298091 -0.642416 -0.884737        X
# 1  2.305701  0.782602 -0.978401  0.306382 -0.699455        Y
# 2  0.265406 -0.736892  0.463714 -0.884278 -0.012699        X
# 3 -0.242388  0.282036  0.938061 -0.507126 -1.149804        Y
# 4  0.176647 -0.426171  1.081067 -2.115161 -0.149782        Z

# %%
df.groupby(['division']).mean()
# Out:
#                  A         B         C         D         E
# division
# X         0.280572 -0.037891  0.380902 -0.763347 -0.448718
# Y         1.031656  0.532319 -0.020170 -0.100372 -0.924629
# Z         0.176647 -0.426171  1.081067 -2.115161 -0.149782

# %%
# 5 주차

# %%
import pandas as pd

sr = pd.Series([100, 200, 300, 400])
sr.index = ['A', 'B', 'O', 'AB']
sr
# Out:
# A     100
# B     200
# O     300
# AB    400
# dtype: int64

# %%
sr1 = pd.Series([10, 20, 30])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({'키':[170, 180, 175], '몸무게':[65, 78, 70]})
df.index = ['스파이더맨', '닥터스트레인지', '아이언맨']
df
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df = pd.read_csv('scores.csv', encoding='cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
#데이터프레임객체.head(n) : 상위 n개 행 보기 (n을 생략하면 디폴트 5개 출력)
#데이터프레임객체.tail(n) : 하위 n개 행 보기 (n을 생략하면 디폴트 5개 출력)
#데이터프레임객체.sample(n) : 랜덤 n개 행 보기 (n을 생략하면 디폴트 1개 출력)
#데이터프레임객체.info() : 데이터프레임의 전반적인 정보 출력
#데이터프레임객체.shape : 데이터프레임의 행,열의 크기 출력
#len(데이터프레임객체) : 데이터프레임의 행의 개수 출력

# %%
df.head()
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df.tail()
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df.sample(3)
# Out:
#            키  몸무게
# 닥터스트레인지  180   78
# 아이언맨     175   70
# 스파이더맨    170   65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 스파이더맨 to 아이언맨
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   키       3 non-null      int64
#  1   몸무게     3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes

# %%
df.shape
# Out:
# (3, 2)

# %%
len(df)

# %%
df.isnull().sum()
# Out:
# 키      0
# 몸무게    0
# dtype: int64

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df_fillna = df.fillna(50)
df_fillna
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df.describe()
# Out:
#            키        몸무게
# count    3.0   3.000000
# mean   175.0  71.000000
# std      5.0   6.557439
# min    170.0  65.000000
# 25%    172.5  67.500000
# 50%    175.0  70.000000
# 75%    177.5  74.000000
# max    180.0  78.000000

# %%
df['국어'].sum()
# Out:
# 775.0

# %%
df.value_counts('영어')
# Out:
# 영어
# 100    3
# 90     2
# 35     1
# 60     1
# 75     1
# 80     1
# 95     1
# dtype: int64

# %%
df['국어']
# Out:
# 0    100.0
# 1     90.0
# 2     95.0
# 3    100.0
# 4      NaN
# 5     70.0
# 6     80.0
# 7     50.0
# 8    100.0
# 9     90.0
# Name: 국어, dtype: float64

# %%
df[['국어', '영어']]
# Out:
#       국어   영어
# 0  100.0   90
# 1   90.0   80
# 2   95.0  100
# 3  100.0  100
# 4    NaN   35
# 5   70.0   75
# 6   80.0   90
# 7   50.0   60
# 8  100.0  100
# 9   90.0   95

# %%
df.loc[1]
# Out:
# 이름     sam
# 국어    90.0
# 영어      80
# 수학    75.0
# Name: 1, dtype: object

# %%
df.loc[[1,2,3]]
# Out:
#        이름     국어   영어     수학
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0

# %%
df.iloc[2]
# Out:
# 이름    vision
# 국어      95.0
# 영어       100
# 수학     100.0
# Name: 2, dtype: object

# %%
df.iloc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
# 시퀀스가 아니라 인덱스로 추출
df.loc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0
# 5     tor   70.0   75   65.0

# %%
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.iloc[1,3]
# Out:
# 75.0

# %%
df.iloc[1:3, 1:3]
# Out:
#      국어   영어
# 1  90.0   80
# 2  95.0  100

# %%
# 6 주차

# %%
# 한글 폰트 처리 : 런타임 다시 시작 필요
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# matplotlib 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')

# - 기호 깨짐 오류 방지
plt.rc('axes', unicode_minus = False)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.plot(x,y, color="blue", marker = 'o', linestyle = ':')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':')
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 40개의 임의의 랜덤값을 생성
aVal = np.random.standard_normal(40)
aVal
# Out:
# array([ 0.6544519 ,  0.48275193, -0.39591646,  0.20527473, -1.30025003,
#         0.50159991,  1.85818804, -2.01815644,  1.37740914, -1.33174965,
#        -0.88114664, -0.02809256,  1.61071941, -0.02420454,  0.96624446,
#         1.58081922,  0.18190867,  1.92714785,  0.83644723,  0.69654699,
#        -0.55985257, -0.75176728,  0.19622499, -0.11496835,  0.27927806,
#        -2.73790481,  2.00216585, -0.48403825,  0.9541253 ,  0.67802274,
#        -1.20363729, -0.61837974,  0.57305984,  1.02694821, -0.86569374,
#         1.37249094, -0.22710038, -0.7806371 ,  1.21957571,  1.92450315])

# %%
# type 확인
# 40개의 랜덤값으로 이루어진 numpy.ndarray형 변수
type(aVal)
# Out:
# numpy.ndarray

# %%
index = range(len(aVal))
plt.plot(index, aVal)

# x축, y축의 범위 설정
plt.xlim(0, 20)
plt.ylim(np.min(aVal) -1, np.max(aVal) + 1)
plt.show()

# %%
# index는 range 형 변수
type(index)
# Out:
# range

# %%
plt.figure(figsize=(7,4))
plt.plot(aVal.cumsum(), 'b', lw= 1.5)
plt.plot(aVal.cumsum(), 'ro')
plt.xlabel('index')
plt.ylabel('aVal')
plt.title('Line Plot')
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
value = np.random.standard_normal((30, 2))
value
# Out:
# array([[-1.51486176,  1.27137221],
#        [ 1.667685  ,  1.22323594],
#        [-0.12344965, -1.44523415],
#        [ 1.84780522,  0.41553251],
#        [ 1.9571583 ,  0.86132874],
#        [-0.20955595,  0.85335395],
#        [ 0.20472402, -2.05806593],
#        [ 0.68897267, -0.5244075 ],
#        [-2.19610038, -0.61306391],
#        [-1.92627439,  1.52308473],
#        [ 1.3541343 , -1.45948413],
#        [-1.43998254, -1.00486486],
#        [-0.62901419, -0.29250023],
#        [-0.00642168,  0.52083693],
#        [-1.48566296, -0.29606847],
#        [ 1.68590885, -0.72080346],
#        [ 1.86302507,  2.14255461],
#        [-0.78389854,  1.1954955 ],
#        [-0.4920822 ,  1.23638428],
#        [ 0.31321313,  0.70421231],
#        [ 0.44589615,  0.90517622],
#        [-1.3240539 , -0.88056559],
#        [ 0.07287433, -0.69180878],
#        [-0.27685172, -1.0827835 ],
#        [ 0.1297099 , -0.06291385],
#        [ 1.50853042, -0.47073719],
#        [-0.69589545,  1.82829654],
#        [ 1.38550033,  0.26318147],
#        [ 0.77229862, -1.01144061],
#        [ 0.77531234, -1.57728302]])

# %%
value[0]
# Out:
# array([-1.51486176,  1.27137221])

# %%
plt.figure(figsize=(10,4))
plt.plot(value[:,0], lw= 1.5)
plt.plot(value[:,1], lw= 1.5)
plt.plot(value, 'ro')
plt.grid(True)
# plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
# 1번째
plt.figure(figsize=(10,5))
plt.subplot(211)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0], 'ro')
plt.grid(True)
plt.legend(loc = 0)
plt.ylabel("value")
plt.title('Line Plot 3')
# 2번째
plt.subplot(212)
plt.plot(value[:,1], 'g', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# 1번째
plt.figure(figsize=(13,5))
plt.subplot(231)
plt.plot(value[:,0], lw= 1.5, label = '1st')
plt.plot(value[:,0], 'co')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel('value')
plt.title('Line Plot 3')
# 2번째
plt.subplot(232)
plt.plot(value[:,0], 'g-.', lw=1.5, label='1st')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 3번째
plt.subplot(233)
plt.plot(value[:,0], 'g', lw=1.5, label='1st')
plt.plot(value[:,0], 'bD')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 4번째
plt.subplot(234)
plt.plot(value[:,1], '*', lw=1.5, label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 5번째
plt.subplot(235)
plt.plot(value[:,1], 'b', lw=1.5, label='2nd')
plt.plot(value[:,1], 'ms')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 6번째
plt.subplot(236)
plt.plot(value[:,1], 'r--', lw=1.5, label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.bar(x,y)
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.barh(x,y)
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.bar(x,y, color="orange", width = 0.5, edgecolor = 'black', hatch = '/')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':', axis = 'y')
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# pandas를 import
import pandas as pd

# score.csv 파일 일기
df = pd.read_csv('scores.csv', encoding='cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
x = df['이름']
y_kor = df['국어']

plt.bar(x, y_kor)
plt.show()

# %%
x = df['이름']
y_kor = df['국어']
y_eng = df['영어']

# 중심을 기준으로 왼쪽/오른쪽에 그래프를 구성
plt.bar(x, y_kor, width = -0.4, align = 'edge', label = '국어')
plt.bar(x, y_eng, width = 0.4, align = 'edge', label = '영어')
plt.title('국어/영어 점수 비교', fontsize = 15)
plt.ylabel('점수')

# 범례
plt.legend() 
plt.show()
# Out:
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\H\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
value = np.random.standard_normal((500,2))
plt.plot(value[:,0], value[:,1], 'ro')
plt.grid(False)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 1')

# %%
plt.figure(figsize=(7,5))
plt.scatter(value[:,0], value[:,1], marker='o')
plt.grid(True)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 2')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 2')

# %%
color = np.random.randint(0,10,len(value))

plt.figure(figsize=(10,5))
plt.scatter(value[:,0], value[:,1], c=color, marker = 'o')
plt.colorbar()
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 3')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 3')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
x = df['total_bill']
y = df['tip']

sns.scatterplot(x,y)
# Out:
# C:\Users\H\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x="day", y = "tip", hue="sex", data=df, palette="muted")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# 7 주차

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline    

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
# seaborn
sns.pairplot(iris)
plt.title("Iris Data Analysis")
# Out:
# Text(0.5, 1.0, 'Iris Data Analysis')

# %%
# kde plot을 적용
sns.pairplot(iris, hue="species", diag_kind='kde')

# %%
sns.boxplot(x='species', y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x='species', y="petal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
# pandas box plot
iris.boxplot(by="species", figsize=(16,8))
# Out:
# array([[<AxesSubplot:title={'center':'petal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'petal_width'}, xlabel='[species]'>],
#        [<AxesSubplot:title={'center':'sepal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
